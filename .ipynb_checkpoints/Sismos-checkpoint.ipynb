# %%
#Importando librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
import folium
from folium.plugins import HeatMap
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tools.eval_measures import rmse

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
#Dimensiones de nuestra base

sismos.shape
# Out:
# (336, 14)

# %%
print("En la provincia de Mendoza durante 2020 hasta la fecha se han registrado {} sismos.".format(sismos.shape[0]))
# Out:
# En la provincia de Mendoza durante 2020 hasta la fecha se han registrado 336 sismos.

# %%
print("En este dataset, se obtienen {} variables a analizar por sismo.".format(sismos.shape[1]))
# Out:
# En este dataset, se obtienen 14 variables a analizar por sismo.

# %%
#Columnas

sismos.columns
# Out:
# Index(['ID', 'Fecha', 'Hora', 'Latitud', 'Longitud', 'Profundidad', 'Magnitud',
#        'Detalle', 'Unnamed: 8', 'Localidad', 'Mapa', 'Is_blank', 'Día Semana',
#        'Profundidad Number'],
#       dtype='object')

# %%
#Primeros valores

sismos.head()
# Out:
#    ID       Fecha      Hora  Latitud  Longitud Profundidad  Magnitud  \
# 0   1  17/09/2020  19:54:36  -33.354   -69.023      11 Km.       2.7
# 1   2  17/09/2020  19:26:03  -32.829   -68.718       8 Km.       2.7
# 2   3  14/09/2020   6:46:19  -34.278   -68.705      15 Km.       3.1
# 3   4  13/09/2020  12:46:46  -33.367   -69.188     138 Km.       2.9
# 4   5  12/09/2020   0:46:30  -32.164   -68.466      84 Km.       2.5
#
#                          Detalle  Unnamed: 8 Localidad  Mapa  Is_blank  \
# 0                            NaN         NaN   MENDOZA  mapa      True
# 1                            NaN         NaN   MENDOZA  mapa      True
# 2  II a III -San Rafael, Mendoza         NaN   MENDOZA  mapa     False
# 3                            NaN         NaN   MENDOZA  mapa      True
# 4                            NaN         NaN   MENDOZA  mapa      True
#
#    Día Semana  Profundidad Number
# 0           4                  11
# 1           4                   8
# 2           1                  15
# 3           7                 138
# 4           6                  84

# %%
#Ultimos 5 valores 

sismos.tail()
# Out:
#       ID       Fecha      Hora  Latitud  Longitud Profundidad  Magnitud  \
# 331  332  03/01/2020  23:10:24  -32.187   -69.336     120 Km.       3.5
# 332  333  03/01/2020  22:01:43  -31.970   -69.158     114 Km.       2.7
# 333  334  03/01/2020   9:38:01  -33.315   -68.893      17 Km.       2.5
# 334  335  01/01/2020  20:34:51  -32.782   -68.889      10 Km.       3.6
# 335  336  01/01/2020  14:35:03  -33.581   -68.830       6 Km.       2.5
#
#                                                Detalle  Unnamed: 8 Localidad  \
# 331                                                NaN         NaN   MENDOZA
# 332                                                NaN         NaN   MENDOZA
# 333                                                NaN         NaN   MENDOZA
# 334  III -Las Heras, Mendoza; III -Ciudad de Mendoz...         NaN   MENDOZA
# 335                                                NaN         NaN   MENDOZA
#
#      Mapa  Is_blank  Día Semana  Profundidad Number
# 331  mapa      True           5                 120
# 332  mapa      True           5                 114
# 333  mapa      True           5                  17
# 334  mapa     False           3                  10
# 335  mapa      True           3                   6

# %%
#Valores nulos 

sismos.isnull().sum()
# Out:
# ID                      0
# Fecha                   0
# Hora                    0
# Latitud                 0
# Longitud                0
# Profundidad             0
# Magnitud                0
# Detalle               289
# Unnamed: 8            336
# Localidad               0
# Mapa                    0
# Is_blank                0
# Día Semana              0
# Profundidad Number      0
# dtype: int64

# %% [markdown]
# <font color= red>Por tema de producción, se recomienda eliminar columna ***unnamed, mapa y localidad*** ya que la base ya se encuentra filtrada en la provincia de Mendoza. Lo mismo, es también </font>

# %%
#Eliminando columnas

sismos.drop(columns = ['Unnamed: 8', "Mapa", "Localidad"], inplace = True)

# %%
#Cantidad de sismos sentidos y no sentidos 

sismos['Is_blank'].value_counts()
# Out:
# True     289
# False     47
# Name: Is_blank, dtype: int64

# %%
#Porcentaje de sismos sentidos y no sentidos

sismos['Is_blank'].value_counts(normalize = True)
# Out:
# True     0.860119
# False    0.139881
# Name: Is_blank, dtype: float64

# %%
#Visualización de sismos sentidos vs no sentidos

sns.countplot(x = 'Is_blank', data = sismos, palette="Set1")
plt.title('Sismos sentidos vs no sentidos en Mendoza', fontsize = 20)
plt.xlabel('¿Tienen descripción?', fontsize = 15)
plt.ylabel('Cantidad', fontsize = 15)
plt.show()

# %%
#Averiguando profundidades: estadística descriptiva 

sismos['Profundidad Number'].describe()
# Out:
# count    336.000000
# mean      68.943452
# std       62.040332
# min        0.000000
# 25%       12.000000
# 50%       29.000000
# 75%      124.250000
# max      235.000000
# Name: Profundidad Number, dtype: float64

# %%
sns.boxplot(sismos['Profundidad Number'])
plt.title('Distribución de profundidades', fontsize = 20)
plt.xlabel('Profunidad')
plt.show()

# %%
#El sismo más profundo 

sismos[sismos['Profundidad Number'] == 235]
# Out:
#       ID       Fecha     Hora  Latitud  Longitud Profundidad  Magnitud  \
# 220  221  09/04/2020  6:52:18  -33.063   -67.737     235 Km.       2.6
#
#     Detalle  Is_blank  Día Semana  Profundidad Number
# 220     NaN      True           4                 235

# %%
#El sismo más superficial

sismos[sismos['Profundidad Number'] == 0]
# Out:
#       ID       Fecha     Hora  Latitud  Longitud Profundidad  Magnitud  \
# 175  176  12/05/2020  2:48:20  -32.153     -68.3       0 Km.       2.5
#
#     Detalle  Is_blank  Día Semana  Profundidad Number
# 175     NaN      True           2                   0

# %%
#Mapeando los dias de la semana 

sismos['Día Semana'] = sismos['Día Semana'].map({1:'lunes', 2:'martes', 3: 'miércoles', 4: 'jueves',
                                                5: 'viernes', 6: 'sábado', 7: 'domingo'})

# %%
mdz_white=folium.Map(location=[-34.1931714, -69.2631543],
                tiles='stamentoner', zoom_start=7)

# %%
display(mdz_white)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitud = list(sismos['Latitud'])
longitud = list(sismos['Longitud'])

# %%
for i in range(len(latitud)):
    folium.Marker([float(latitud[i]), float(longitud[i])],popup='Centros de Salud',
                   icon=folium.Icon(color='red')).add_to(mdz_white)

# %%
display(mdz_white)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
heat_df = sismos[['Latitud', 'Longitud']]

# %%
heat_data = [[row['Latitud'],row['Longitud']] for index, row in heat_df.iterrows()]

# %%
map_hooray = folium.Map(location=[-34.1931714, -69.2631543],
                    zoom_start =7)
HeatMap(heat_data).add_to(map_hooray)

# %%
map_hooray
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
